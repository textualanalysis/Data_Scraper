# %%
pip install -U textblob
# Out:
# Requirement already up-to-date: textblob in c:\users\samia\anaconda3\lib\site-packages (0.15.3)
# Requirement already satisfied, skipping upgrade: nltk>=3.1 in c:\users\samia\anaconda3\lib\site-packages (from textblob) (3.4.4)
# Requirement already satisfied, skipping upgrade: six in c:\users\samia\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Unidecode
# Out:
# Requirement already satisfied: Unidecode in c:\users\samia\anaconda3\lib\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#important file to download 

######Do this first
import nltk
nltk.download('averaged_perceptron_tagger')
##############################################
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\samia\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# Option file location when the data is not saved in current directory (full path)
#file_location ='C:/Users/samia/new script/dataset/Covid19/'

# %%
import tweepy
import re
import datetime
import pandas as pd

####input your credentials here

CONSUMER_KEY = 'AvfeBIaSI75L8621H66sRKZc7'
CONSUMER_SECRET = 'l80lgvgDMyYBz5eblitQeGaJ4cngtGWvpb0G8ZSk7pA81h6ypy'

ACCESS_TOKEN ='1176149741232635905-FiWCMtmkDOrK4ULzFGKoJUat0wE9ij'
ACCESS_TOKEN_SECRET = 'HKMgQJLSfLQ2yoNpzcj9f0hCnVgJjowNEQtFoAiia34bd'

# %%
def auth(consumer_key, consumer_secret, access_token, access_token_secret):
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)
    return api

# %%
api = auth(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

# %%
#key_words='ottawa AND ((oc AND transpo) OR lrt OR otrain)'
#key_words='toronto AND (quayside OR blocksidewalk)'
key_words='ottawa AND (corona OR virus OR pandemic OR covid OR coronavirus)'
#key_words='toronto AND (corona OR virus OR pandemic OR covid OR coronavirus)'
#key_words='vancouver AND (corona OR virus OR pandemic OR covid OR coronavirus)'
#filter to avoid the retweets text
filter_key_words = key_words + " -filter:retweets"

# %%
#weeknumber function return the week number of month by passing date as a parameter
def weeknum(d):

    if d >= 22:
        weeknum = 4
    elif (d >= 15):
        weeknum = 3
    elif (d > 7):
        weeknum = 2
    else: 
        weeknum = 1
    return (str(weeknum))

# %%
sincedate = '2020-09-01'
untildate='2020-10-08'

# %%
tweets = tweepy.Cursor(api.search, q=filter_key_words , since=sincedate, lang='en', tweet_mode='extended').items(10000)
tweet_detail = [[tweet.full_text.replace('\n',' ').encode('utf-8'),tweet.created_at.strftime("%m/%d/%Y %H:%M:%S"),"Month_"+tweet.created_at.strftime("%m")+" Week "+weeknum(int(tweet.created_at.strftime("%d"))),tweet.created_at.strftime("%m"),tweet.user.location] for tweet in tweets]
# Out:
# Rate limit reached. Sleeping for: 793

# %%
dataset = pd.DataFrame(data=tweet_detail, columns=['text', 'date','Week','Month','location'])

# %%
dataset
# Out:
#                                                    text                 date  \
# 0     b"Ontario's Public Health Officials say the sp...  10/08/2020 19:14:20
# 1     b'Wedding results in 22 COVID cases, hundreds ...  10/08/2020 19:11:43
# 2     b'Wedding results in 22 COVID cases, hundreds ...  10/08/2020 19:11:31
# 3     b'@zibzer It makes way for someone else\xe2\x8...  10/08/2020 19:10:46
# 4     b'Ottawa sewage study detects COVID-19 doublin...  10/08/2020 19:09:47
Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:915: UserWarning: Ignoring URL 'https://t.co/bcHYOtIsj7%20@VeraEtches%20we%20fine%20people%20for%20being%20stopped%20at%20a%20red%20light%20holding%20a%20phone,%20but%20not%20obstruction%20and%20actively%20jeopardizing%20lives%20during%20a%20pandemic?%20This%20inaction%20is%20why%20cases%20are%20spiking,%20@OttawaPolice%20are%20as%20impotent%20as%20your%20policies.%20@CBCOttawa' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\samia\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:915: UserWarning: Ignoring URL 'https://t.co/WTEoFjIyEe%20This%20is%20easily%20explained.%20As%20someone%20recently%20commented%20on%20the%20CBC%20website,%20,%20'If%20a%20graphics%20designer%20is%20appointed%20as%20a%20health%20minister%20because%20she%20fits%20the%20quota,%20then%20no%20one%20should%20be%20surprised%20that%20she%20has%20no%20clue%20on%20how%20to%20protect%20the%20public.'%20https://t.co/j48eq2T606' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\samia\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def cleaning_textual(fname):
    #Importing libraries

    import re
    import string
    import nltk
    from textblob import Word
    from nltk.corpus import wordnet
    from nltk.stem import WordNetLemmatizer
    from nltk.tokenize import TweetTokenizer 
    from nltk.corpus import stopwords
    import unicodedata
    from unidecode import unidecode
           
    # importing pandas package 
    import pandas as pd    
    df = pd.read_excel(fname+'.xlsx') 
    # Converting to lowercase
 
    df['tweet_clean_textual']= df['text'].str.lower()
    
    
    df['tweet_clean_textual']= df['tweet_clean_textual'].fillna("") 

    def deEmojify(inputString):
        return inputString.encode('ascii', 'ignore').decode('ascii')

        
    # Removing emoji
    df['tweet_clean_textual'] = df['tweet_clean_textual'].apply(lambda x: deEmojify(x))

    #Removing HTTP links
    df['tweet_clean_textual']= df['tweet_clean_textual'].str.replace(r"(https?\://)\S+", ' ')   
                             
    #Removing WWW links    
    df['tweet_clean_textual']= df['tweet_clean_textual'].str.replace(r'www.[A-Za-z0-9./?//:]\S+',' ') 

    # Removing hashtags
    df['tweet_clean_textual']= df['tweet_clean_textual'].str.replace(r'#[A-Za-z0-9]\S+', ' ')

    # Removing mentions  
    df['tweet_clean_textual']= df['tweet_clean_textual'].str.replace(r'@[A-Za-z0-9]\S+', ' ')

    #removing numbers
    df['tweet_clean_textual']= df['tweet_clean_textual'].str.replace(r'[0-9]+', ' ')

    #removing special character 
    df['tweet_clean_textual']= df['tweet_clean_textual'].str.replace(r'[^a-zA-Z0-9\s]+', ' ')

    #removing extra whitespaces
    df['tweet_clean_textual']= df['tweet_clean_textual'].str.strip()

    # Init Lemmatizer
    lemmatizer = WordNetLemmatizer()

    # Get Part-of-speech (pos) tag of words of the sentence 
    def get_wordnet_pos(word):
        tag = nltk.pos_tag([word])[0][1][0].upper()

        tag_dict = {"J": wordnet.ADJ,
                    "N": wordnet.NOUN,
                    "V": wordnet.VERB,
                    "R": wordnet.ADV}

        return tag_dict.get(tag, wordnet.NOUN)

    # Lemmatize a Sentence with the appropriate Part-of-speech tag
    df['tweet_clean_textual'] = df['tweet_clean_textual'].apply(lambda x: " ".join([lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in x.split()]))

    #remove_stop_words using NLTK library
    stop = stopwords.words('english')

    df['tweet_clean_textual']=df['tweet_clean_textual'].apply(lambda x: " ".join([item for item in x.split() if item not in stop]))


    #Remove short words with less than 3 letters and remove_stop_words using  txt file
    def remove_short_stop_words(row):
        review = row['tweet_clean_textual']
        #Tokenize the sentence by using word_tokenize method from nltk library
        tokens = TweetTokenizer().tokenize(review)
        token_words = [w for w in tokens if len(w) >= 3]
        with open("additional_stop_words.txt",'r') as stopwordFile:
            #Tokenize the sentence by using split() method  from String library
            b=stopwordFile.read().split() 
            #remove_stop_words using txt file (additinal_stop_words)
            stop_words = [word for word in token_words if word not in b]
            joined_words = ( " ".join(stop_words))
        
            stopwordFile.close()

            return joined_words

    # Call the remove_short_words  function
    df['tweet_clean_textual'] = df.apply(remove_short_stop_words, axis=1)
    df.to_excel(filename+'.xlsx',encoding='utf-8',index=False) 

    # display 
    return df

# %%
cleaning_textual(filename)
# Out:
#                                                    text                 date  \
# 0     Ontario's Public Health Officials say the spre...  10/08/2020 19:14:20
# 1     Wedding results in 22 COVID cases, hundreds se...  10/08/2020 19:11:43
# 2     Wedding results in 22 COVID cases, hundreds se...  10/08/2020 19:11:31
# 3     @zibzer It makes way for someone else’s busine...  10/08/2020 19:10:46
# 4     Ottawa sewage study detects COVID-19 doubling ...  10/08/2020 19:09:47
# 5     How is there no mobile testing team that can b...  10/08/2020 19:06:29
# 6     COVID-19.   We remain so grateful for your sup...  10/08/2020 19:06:08
# 7     An Ottawa Wedding Led To 22 Cases Of COVID-19 ...  10/08/2020 19:05:03
# 8     Ottawa Public Health reports 183 new cases of ...  10/08/2020 19:04:52
# 9     Ottawa sewage study detects COVID-19 doubling ...  10/08/2020 19:04:06
# 10    Ottawa Public Health reports 183 new cases of ...  10/08/2020 19:03:47
# 11    Ottawa has lifted COVID-19 cross-border travel...  10/08/2020 19:01:01
# 12    COVID-19 outbreaks declared at for new Ottawa ...  10/08/2020 19:00:45
# 13    COVID-19 outbreaks declared at for new Ottawa ...  10/08/2020 19:00:44
# 14    IRCC announces increased funding toward settle...  10/08/2020 19:00:01
# 15    @Maximus_ray @JordanMcNaught @ctvottawa It is ...  10/08/2020 18:58:14
# 16    Covid walk today @ Ottawa, Ontario https://t.c...  10/08/2020 18:56:15
# 17    @OttawaHospital any #Sociology experts availab...  10/08/2020 18:54:53
# 18    "According to McCurdy, Ottawa Public Health to...  10/08/2020 18:54:43
# 19    Ottawa with another single-day record in new C...  10/08/2020 18:54:27
# 20    Ottawa Pumps $30 Million To Help New Canadians...  10/08/2020 18:53:00
# 21    Ottawa sewage study detects COVID-19 doubling ...  10/08/2020 18:52:53
# 22    Sitting in for the fabulous ⁦@radioKristy⁩ tod...  10/08/2020 18:51:06
# 23    After being separated for months due to COVID-...  10/08/2020 18:50:51
# 24    After being separated for months due to COVID-...  10/08/2020 18:50:51
# 25    @NoLore @cyclingzealot So speeding bikes are a...  10/08/2020 18:46:20
# 26    @RebelNewsOnline @AndrewSaysTV That’s why covi...  10/08/2020 18:45:39
# 27    🇺🇸 Eagle Air Transport Inc-owned 1968 Shorts S...  10/08/2020 18:44:14
# 28    Ottawa Pumps $30 Million To Help New Canadians...  10/08/2020 18:42:56
# 10    ottawa public health report new case covid ott...
# 11    ottawa lift covid cross border travel restrict...
# 12    covid outbreak declare new ottawa school ctv e...
# 13    covid outbreak declare new ottawa school ctv e...
# 14    ircc announces increase funding toward settlem...
# 15    article ottawa public health report people ott...
# 16                      covid walk today ottawa ontario
# 17    expert available help understand ottawa work h...
# 18    accord mccurdy ottawa public health told safe ...
# 19              ottawa single record new covid case via
# 20       ottawa pump million help new canadian pandemic
# 21    ottawa sewage study detects covid double past ...
# 22    sit fabulous today debate follow new case coun...
# 23    separate month due covid travel restriction ca...
# 24    separate month due covid travel restriction ca...
# 25    speed bike hassle especially covid cycle walk ...
# 26    thats covid joke hoax play canadian fool lie p...
# 27    eagle air transport inc short skyvan formerly ...
# 28       ottawa pump million help new canadian pandemic
# 29       ottawa pump million help new canadian pandemic
# ...                                                 ...
# 2704  follow covid isolation rule face daily fine ot...
# 2705  fellow year really disappointed pandemic come ...
# 2706  carrie one pandemic rear view mirror wil recon...
# 2707  canadian die covid link residential care littl...
# 2708       holy cross catholic secondary school closure
# 2709  oseg cut close half place staff cite brutal pa...
# 2710  birthday backyard lunchroom people ottawa expo...
# 2711  aside williams say today positivity toronto pe...
# 2712    time spare long term care home brace wave covid
# 2713  come ottawa pull please ottawa medical officer...
# 2714  ceo tell employee job cut harsh result brutal ...
# 2715  birthday backyard lunchroom people ottawa expo...
# 2716  ken please covid come ottawa canada please con...
# 2717  coronavirus ottawa ease border restriction com...
# 2718  bit stupid really understand quarantine ottawa...
# 2719                  look ontario ltc covid commission
# 2720  school board ottawa small class covid case per...
# 2721  across ottawa covid case confirm school class ...
# 2722  covid limit close contact household say oph mo...
# 2723                           time burst social bubble
# 2724  ottawa public health report new coronavirus ca...
# 2725  disturb include reveal paragraph ottawa citize...
# 2726  sound like leave ottawa thought bring reliable...
# 2727  letter sign doctor amp professor medicine univ...
# 2728       current trajectory ottawa covid case per mid
# 2729  reform make benefit generous accessible three ...
# 2730  ottawa unveils guideline deal rapid covid test...
# 2731  canada snap covid vaccine expense poorer count...
# 2732  toole full covid commie test cause current cas...
# 2733  please help understand article coronavirus ott...
#
# [2734 rows x 6 columns]

# %%
pip install emoji --upgrade
# Out:
# Requirement already up-to-date: emoji in c:\users\samia\anaconda3\lib\site-packages (0.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def cleaning_sentiment(fname):
    #Importing libraries

    import re
    import string
    import emoji
    import nltk
    from textblob import Word
    from nltk.corpus import wordnet
    from nltk.stem import WordNetLemmatizer
    from nltk.tokenize import TweetTokenizer
    
    
    # Happy Emoticons
    emoticons_happy = set([
    ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
    ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
    '<3'
    ])
    # Sad Emoticons
    emoticons_sad = set([
    ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', ':3', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', ':{', '>:\\', ';('
    ])
    
    # importing pandas package 
    import pandas as pd 
    
    df = pd.read_excel(fname+'.xlsx') 
    # Converting to lowercase
 
    df['tweet_clean_sentiment']= df['text'].str.lower()
    df['tweet_clean_sentiment']= df['tweet_clean_sentiment'].fillna("") 
    
    # Function for converting emoticons to sentiments (happy or sad)
    def convert_emoticons(row):
        text = row['tweet_clean_sentiment']
        tweet_tokenizer = TweetTokenizer()

        for word in tweet_tokenizer.tokenize(text):
           
            if word in emoticons_sad:         
                text = text.replace( word, ' sad ') 
                
            elif word in emoticons_happy:
                text = text.replace( word, ' happy ')
        return text
    
    # Convert emoticons to words {sad or happy}
    df['tweet_clean_sentiment'] = df.apply(convert_emoticons, axis=1)
    
    # Convert emoji to words
    df['tweet_clean_sentiment'] = df['tweet_clean_sentiment'].apply(lambda x: emoji.demojize(x))

    #replace apostrophe (’) by (') then apply the decontracted function 
    df['tweet_clean_sentiment']= df['tweet_clean_sentiment'].str.replace(r'\’', '\'')

    # Expending  contraction function
    def decontracted(row):
        sentence=row['tweet_clean_sentiment'] 
        # specific
        sentence = re.sub(r"won\'t", "will not", sentence)       
        sentence = re.sub(r"can\'t", "cannot", sentence)
        sentence = re.sub(r"shan\'t", "shall not", sentence)
        sentence = re.sub(r"wanna", "want to", sentence) 
        sentence = re.sub(r"let's", "let us", sentence)
        sentence = re.sub(r"innit", "is it not", sentence)
        sentence = re.sub(r"gonna", "going to", sentence)
        sentence = re.sub(r"gotta", "got to", sentence)

        # general
        sentence = re.sub(r"n\'t", " not", sentence)
        sentence = re.sub(r"\'re", " are", sentence)
        sentence = re.sub(r"\'s", " is", sentence)
        sentence = re.sub(r"\'d", " would", sentence)   
        #sentence = re.sub(r"\'d", " had", sentence)    
        sentence = re.sub(r"\'ll", " will", sentence)
        #sentence = re.sub(r"\'ll", " shall", sentence)
        sentence = re.sub(r"\'t", " not", sentence)
        sentence = re.sub(r"\'ve", " have", sentence)
        sentence = re.sub(r"\'m", " am", sentence)
        
        return sentence
    # Expending  contraction
    df['tweet_clean_sentiment'] = df.apply(decontracted, axis=1)
    
    #Removing HTTP links
    df['tweet_clean_sentiment']= df['tweet_clean_sentiment'].str.replace(r"(https?\://)\S+", ' ')   
                             
    #Removing WWW links    
    df['tweet_clean_sentiment']= df['tweet_clean_sentiment'].str.replace(r'www.[A-Za-z0-9./?//:]\S+',' ') 

    # Removing hashtags
    df['tweet_clean_sentiment']= df['tweet_clean_sentiment'].str.replace(r'#[A-Za-z0-9]\S+', ' ')

    # Removing mentions  
    df['tweet_clean_sentiment']= df['tweet_clean_sentiment'].str.replace(r'@[A-Za-z0-9]\S+', ' ')

    #removing numbers
    df['tweet_clean_sentiment']= df['tweet_clean_sentiment'].str.replace(r'[0-9]+', ' ')

    #removing special character 
    df['tweet_clean_sentiment']= df['tweet_clean_sentiment'].str.replace(r'[^a-zA-Z0-9-\s]+', ' ')

    #removing extra whitespaces
    df['tweet_clean_sentiment']= df['tweet_clean_sentiment'].str.strip()

    # Init Lemmatizer
    lemmatizer = WordNetLemmatizer()

    # Get Part-of-speech (pos) tag of words of the sentence 
    def get_wordnet_pos(word):
        tag = nltk.pos_tag([word])[0][1][0].upper()

        tag_dict = {"J": wordnet.ADJ,
                    "N": wordnet.NOUN,
                    "V": wordnet.VERB,
                    "R": wordnet.ADV}

        return tag_dict.get(tag, wordnet.NOUN)

    # Lemmatize a Sentence with the appropriate Part-of-speech tag
    df['tweet_clean_sentiment'] = df['tweet_clean_sentiment'].apply(lambda x: " ".join([lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in x.split()]))

    # Connect with NO 
    df['tweet_clean_sentiment']= df['tweet_clean_sentiment'].str.replace(r'no ', 'no_')

    # Connect with NOT 
    df['tweet_clean_sentiment']= df['tweet_clean_sentiment'].str.replace(r'not ', 'not_')


    #Remove stop_words using stop txt file
    def remove_stop_words(row):
        with open("stop.txt",'r') as stopwordFile:
            #Tokenize the sentence by using split() method  from String library
            b=stopwordFile.read().split() 
            review = row['tweet_clean_sentiment']
            tokens = TweetTokenizer().tokenize(review)
            stop_words = [word for word in tokens if word not in b]
            remove_words = ( " ".join(stop_words))
            stopwordFile.close()
            return remove_words
        
        # Call the remove_stop_words function   
    df['tweet_clean_sentiment'] = df.apply(remove_stop_words, axis=1)

    #Remove short words with less than 3 letters
    def remove_short_words(row):
        review = row['tweet_clean_sentiment']
        #Tokenize the sentence by using word_tokenize method from nltk library
        tokens = TweetTokenizer().tokenize(review)
        token_words = [w for w in tokens if len(w) >= 3]
        joined_words = ( " ".join(token_words))
        return joined_words

    # Call the remove_short_words function
    df['tweet_clean_sentiment'] = df.apply(remove_short_words, axis=1)
  
    # Replace hyphen "-" with underscore "_". 
    df['tweet_clean_sentiment']= df['tweet_clean_sentiment'].str.replace(r'-', '_')
    df.to_excel(filename+'TextualSentimentclean.xlsx',encoding='utf-8',index=False) 
   
    return df

# %%
cleaning_sentiment(filename)
# Out:
#                                                    text                 date  \
# 0     Ontario's Public Health Officials say the spre...  10/08/2020 19:14:20
# 1     Wedding results in 22 COVID cases, hundreds se...  10/08/2020 19:11:43
# 2     Wedding results in 22 COVID cases, hundreds se...  10/08/2020 19:11:31
# 3     @zibzer It makes way for someone else’s busine...  10/08/2020 19:10:46
# 4     Ottawa sewage study detects COVID-19 doubling ...  10/08/2020 19:09:47
# 5     How is there no mobile testing team that can b...  10/08/2020 19:06:29
# 6     COVID-19.   We remain so grateful for your sup...  10/08/2020 19:06:08
# 7     An Ottawa Wedding Led To 22 Cases Of COVID-19 ...  10/08/2020 19:05:03
# 8     Ottawa Public Health reports 183 new cases of ...  10/08/2020 19:04:52
# 9     Ottawa sewage study detects COVID-19 doubling ...  10/08/2020 19:04:06
# 10    Ottawa Public Health reports 183 new cases of ...  10/08/2020 19:03:47
